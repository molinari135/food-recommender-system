# %%
import pandas as pd

# %%
food_seasonality = pd.read_csv(r'..\data\raw\food-seasonality.csv')
nutri_facts_common = pd.read_csv(r'..\data\raw\nutritional-facts-for-most-common-foods-and-products.csv')

# %%
food_seasonality
# Out:
#                                  Food Seasonality IT
# 0                           Artichoke   XXXX000000XX
# 1                           Asparagus   00XXXX000000
# 2                         Beans, Lima   000XXXX00000
# 3                           Beetroots   XX00000XXXXX
# 4                            Broccoli   XXXX00000XXX
# 5                    Brussels sprouts   XXXX00000XXX
# 6                         Cauliflower   XXXX00000XXX
# 7                              Celery   000XXXXXXXX0
# 8                            Collards   XXXX00000XXX
# 9              Corn, cooked or canned   XXXX00000XXX
# 10                          Cucumbers   00000XXXX000
# 11                           Eggplant   00000XXXXX00
# 12                             Endive   X000000000XX
# 13                               Kale   XXX000000000
# 14                     Mustard greens   0000XXXXXX00
# 15                           Parsnips   XXX000000XXX
# 16                               Peas   000XXX000000
# ...

# %%
current_month_index = 0  # January corresponds to the first character in the string

# Filter rows where the current month's seasonality (first character) is 'X'
available_this_month = food_seasonality[food_seasonality["Seasonality IT"].str[current_month_index] == "X"]

# Print or return the filtered results
print("Available in January:")
print(available_this_month)
# Out:
# Available in January:
#                       Food Seasonality IT
# 0                Artichoke   XXXX000000XX
# 3                Beetroots   XX00000XXXXX
# 4                 Broccoli   XXXX00000XXX
# 5         Brussels sprouts   XXXX00000XXX
# 6              Cauliflower   XXXX00000XXX
# 8                 Collards   XXXX00000XXX
# 9   Corn, cooked or canned   XXXX00000XXX
# 12                  Endive   X000000000XX
# 13                    Kale   XXX000000000
# 15                Parsnips   XXX000000XXX
# 19                Radishes   XXX0000000XX
# 20                 Spinach   XXXXX000XXXX
# 21   Squash Winter, mashed   XXXXX000XXXX
# 22          Sweet potatoes   XXX000000XXX
# 25           Turnip greens   XX000000000X
# 26        Turnips, steamed   XX000000000X
# 27             Apples, raw   XXXX000XXXXX
# 41     Oranges 3" diameter   XXXX000000XX
# 44      Pears Raw, 3 by 2V   XXXXX00XXXXX
# 51              Tangerines   XX0000000XXX
